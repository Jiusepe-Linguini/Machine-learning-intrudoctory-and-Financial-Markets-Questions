# %%
1. Which of these is not a source of free financial data?
Bloomberg*
Quandl 
FRED 
DukasCopy

2.What are the attributes of structured data?
Is only numerical data
Has a common form*
Requires a lot of data cleaning 
Is difficult to use

3.What FX pair is not in the correct convention?
EUR/USD
GBP/EUR*
GBP/JPY
NOK/SEK

4.What does the information ratio measure?
Risk adjusted returns*
Annualised returns 
Volatility divided by returns 
Drawdowns

5.When will carrying returns be important?
When there is a large interest rate differential between the base and terms currencies*
When there is a small interest rate differential between the base and terms currencies 
When the strategy is not always long carry
When we are trading EUR/GBP

6.Which of these are not likely to be a driver for G10 FX?
Trend
Relative interest rate policy
Positioning and sentiment
Price of an illiquid asset in a frontier market*

7.Which of these is the correct syntax for a 200 period SMA in Pandas? (assuming df variable is a DataFrame)
df.rolling(200, min_periods=1).mean()*
df.rolling(200, min_periods=1).average() 
df.rolling(200).sum() 
df.rolling(200).average()

8.If we have a DataFrame of prices (df), what does the following calculate? df/ df.shift(1) - 1.0
Simple returns*
Volatility 
Drawdowns 
Information ratio

9.What's the output of this function, where df are market prices and df_sma are the simple moving average of market prices? 
np.where(df > df_sma, 1.0, -1.0)

Long trading signals if price if above SMA & short trading signals if price is below SMA*
Volatility of returns
Long trading signals if price if below SMA & short trading signals if price is above SMA 
Classifies if returns are positive or negative

10.Why are Parquet files better than CSV?
File sizes are smaller than CSV*
They are quicker to parse than CSV* 
They are not as commonly used as CSV 
None of the above

11.What does the following calculate, where df_tick contains columns for bid, ask and mid prices? 10000 * \
(df_tick['EURUSD.ask']-df_tick['EURUSD.bid']) / df_tick['mid']
Bid/ask spread in basis points*
Bid/ask spread in percentage 
Bid/mid spread in basis points 
Ask/mid spread in percentage

12.What does this function do, assuming df_tick is a DataFrame with market data? 
df_tick.resample("1h").last()

Gives you the last point of the time series*
Gives you the last point of every hour in the time series 
Gives you the average of every hour in the time series 
Gives you the high of every hour in the time series

13.Which volatility estimator is this (assuming df is a DataFrame with price data)?
def vol(df, window=5, trading_periods=252): 
    rs = (1.0 / (4.0 * math.log(2.0))) * ((df['high'] / df['low']).apply(np.log))**2.0 
    def f(v): return trading_periods * v.mean()**0.5 
    return rs.rolling(window=window, center=False).apply(func=f)
    
Close to close volatility estimator 
Hodges-Tompkins volatility estimator 
Parkinson volatility estimator*
Garman-Klass volatility estimator

14.What does Dash do?
Creates Python based web dashboards*
Test harness
Create web dashboards where you need to do a lot of 
JavaScript coding None of the above

15.Which of these are true for Dash callbacks?
A callback event is triggered when an input is changed* 
A callback event can have multiple outputs*
A callback event can have multiple inputs*
A callback event can only have a graph output

16.What does a CSS stylesheet do?
Can be used to change the fonts of a web page*
Can be used to test a web page 
Can be used to write Python code 
None of the above

17.Which of the following are true about this code? 
@xw.func
def hello(name):
return "hello {0}".format(name)

This code is a Python function which can be used in Excel as a UDF*
This code prints a name in the Python console 
The code has no input parameters
This code has syntax errors and won't run

18.What does Prophet library do?
Gives advice on improving Python code
Forecast time series*
Used for linear algebra 
Monte-Carlo simulations

19.Which of these is not a visualization library in Python
Plotly
Matplotlib 
Bokeh 
Shiny*

20.Which of these libraries would you use for time series?
NumPy
Pandas*
Matplotlib 
Plotly

21.What are Pandas built on top of?
NumPy*
Lists 
a 
Sets

22.Which library has built in functionality for a linear regression?
NumPy 
threading 
Scikit-learn*
BeautifulSoup

23.Which of these are not functions in Pandas?
align 
resample 
join 
follow*

24.With NumPy, what does the ones functions do?
It create an array only with entries of one*
It returns the first column of an array 
It returns the first row of an array
None of the above

25.How can you speed up computations with Pandas?
Use for loops
Rewrite with NumPy only*
Create large DataFrames 
None of the above

26.What 's Cython?
A slower version of Python
A subset of Python that can be compiled to machine code*
An easier to use version of Python
A totally different language to Python

27.If you think your data has very non-linear patterns, which statistical model might work better?
Linear regression
Ridge regression
Logistic regression 
Support vector machine*

28.What's the difference between a pandas Series and DataFrame?
You can only resample DataFrames
A Series has an index, and DataFrames don't
You can add Series, but you can't add DataFrames
A DataFrame can hold more than one column variable*

29.Which of these is a Python list?
[1,2,3]*
(1,2,3) 
{1:2, 3:4}
1

30.What's the difference between a set and a list? 
A set can only have numbers
A list can have duplicates*
A list can only have strings
The size of a set is more limited

31.Which one of these is most likely to be a float
1.01*
1 
a 
x

32.Which of these is cloud based service 
Jupyter notebooks
Azure notebooks*
PyCharm 
Notepad

33.What's wrong with this code? 
def hello_world()
print('hello') 
print('hello')

Missing : in first line*
Missing ) in first line
Incorrect spacing at start of lines 
There shouldn't be a def

34.What does the pickle library do?
It serializes Python objects so they can be saved to disk*
It only reads and writes text data
It is primarily used to speed up code 
It can be used to reduce errors

35.What would be a good use of the Python threading library for?
To speed up heavily IO bound operations (like downloading webpages)*
For testing only
To make code easier to read
To speed up heavily CPU bound operations (eg. option pricing)

36.What would you use urllib.request for? 
Reading files from disk
Reading web pages*
Drawing pictures
To do string processing

37.What does a dictionary consist of?
keys and values*
keys only 
values only 
lists

38.What is this structure {}? 
Something else
An empty list
An empty set
An empty dictionary*
