# %%
1. Which of these is not a visualization library in Python
Plotly
Matplotlib
Bokeh
Shiny*

2. Which of these libraries would you use for time series?
NumPy
Pandas*
Matplotlib
Plotly

3. What is Pandas built on top of?
NumPy*
Lists
a
Sets
4. Which library has built-in functionality for linear regression?
NumPy
threading
Scikit-learn*
BeautifulSoup

5. Which of these are not functions in Pandas?
align
resample
join
follow*

6. With NumPy, what does the ones functions do?
It create an array only with entries of one*
It returns the first column of an array
It returns the first row of an array
None of the above

7. How can you speed up computations with Pandas?
Use for loops
Rewrite with NumPy only*
Create large DataFrames
None of the above

8. What's Cython?
A slower version of Python
A subset of Python that can be compiled to machine code*
An easier to use version of Python
A totally different language to Python

9. If you think your data has very non-linear patterns, which statistical model might work better?
Linear regression
Ridge regression
Logistic regression
Support vector machine*

10. What's the difference between a pandas Series and DataFrame?
You can only resample DataFrames
A Series has an index, and DataFrames don't
You can add Series, but you can't add DataFrames
A DataFrame can hold more than one column variable*

1. Which of these is a Python list?
[1,2,3]*
(1,2,3)
{1:2, 3:4}
1

2. What's the difference between a set and a list?
A set can only have numbers
A list can have duplicates*
A list can only have strings
The size of a set is more limited

3. Which one of these is most likely to be a float
1.01*
1
a
x

4. Which of these is cloud based service
Jupyter notebooks
Azure notebooks*
PyCharm
Notepad

5. What's wrong with this code?
def hello_world()
    print('hello')
    print('hello')

Missing : in first line*
Missing ) in first line
Incorrect spacing at start of lines
There shouldn't be a def

6. What does the pickle library do?
It serializes Python objects so they can be saved to disk*
It only reads and writes text data
It is primarily used to speed up code
It can be used to reduce errors

7. What would be a good use of the Python threading library for?
To speed up heavily IO bound operations (like downloading webpages)*
For testing only
To make code easier to read
To speed up heavily CPU bound operations (eg. option pricing)

8. What would you use urllib.request for?
Reading files from disk
Reading web pages*
Drawing pictures
To do string processing

9. What does a dictionary consist of?
keys and values*
keys only
values only
lists

10. What is this structure {}?
Something else
An empty list
An empty set
An empty dictionary*
